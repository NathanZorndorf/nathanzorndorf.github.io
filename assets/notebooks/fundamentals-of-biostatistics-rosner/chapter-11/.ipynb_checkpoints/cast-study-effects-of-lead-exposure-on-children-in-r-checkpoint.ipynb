# %% [markdown]
# The data for this notebook can be found on Rebecca Burke's faculty website here: http://faculty.cascadia.edu/rburke/<br>
# specifically > http://faculty.cascadia.edu/rburke/iqlead.csv

# %%
library(tidyverse)

library(haven)

library(data.table)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
#
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %%
df <- read.csv("http://faculty.cascadia.edu/rburke/iqlead.csv")

# %%
head(df, 2)
# Out:
#   LEAD AGE SEX YEAR1 YEAR2 IQV IQP IQF
# 1 1    11  1   25    18    61  85  70
# 2 1     9  1   31    28    82  90  85

# %%
# create long-form dataframe
# dfl <- melt(df, id.vars = LEAD:IQF)
dfl <- df %>% gather()
head(dfl, 3)
# Out:
#   key  value
# 1 LEAD 1
# 2 LEAD 1
# 3 LEAD 1

# %% [markdown]
# Full raw data available via David Banks' faculty repository @ http://www2.stat.duke.edu/~banks/111-labs.dir/lab4.dir/

# %%
all_data <- read_dta(file = "http://www2.stat.duke.edu/~banks/111-labs.dir/lab4.dir/lead.dta")
head(all_data, 2)
# Out:
#   ID  area age  sex info comp ar ds vraw pc ... tapsright tapsleft
# 1 101 3    1101 1   3    4    3  5  15   10 ... 16        16
# 2 102 3     905 1   7    9    7  6  29    8 ... 17        16
#   reactionright reactionleft auditoryright auditoryleft fingerright fingerleft
# 1 38            27           36            25           72          52
# 2 19            18           23            28           61          48
#   wwps Agemo
# 1 NA   133
# 2  0   113

# %%
colnames(all_data)
# Out:
#  [1] "ID"            "area"          "age"           "sex"
#  [5] "info"          "comp"          "ar"            "ds"
#  [9] "vraw"          "pc"            "bd"            "oa"
# [13] "cod"           "praw"          "hhindex"       "iqv"
# [17] "iqp"           "iqf"           "typeiq"        "group"
# [21] "ld72"          "ld73"          "frst2yrs"      "totyrs"
# [25] "pica"          "colic"         "clumsiness"    "iritability"
# [29] "convulsions"   "tapsright"     "tapsleft"      "reactionright"
# [33] "reactionleft"  "auditoryright" "auditoryleft"  "fingerright"
# [37] "fingerleft"    "wwps"          "Agemo"

# %%
options(repr.plot.width=20, repr.plot.height=5) # set plot figure size

# %%
# create a histogram of each of the continuous data variables
ggplot(data = dfl, mapping = aes(value)) + 
    geom_histogram(bins=10) + 
    facet_grid(.~key, scales = 'free_x')
# Out:
# plot without title

# %%
colnames(df)
# Out:
# [1] "LEAD"  "AGE"   "SEX"   "YEAR1" "YEAR2" "IQV"   "IQP"   "IQF"

# %%
df$SEX <- as.factor(df$SEX)

# %%
df$LEAD <- as.factor(df$LEAD)

# %%
# create a box plot of IQF, colored by LEAD
ggplot(df) + 
    geom_boxplot(mapping = aes(y = IQF, color = LEAD))
# Out:
# plot without title

# %%
# # create a boxplot of YEAR1, colored by LEAD
# ggplot(df) + 
#     geom_boxplot(mapping = aes(y = YEAR1, color = LEAD))

# %%
# # create a boxplot of YEAR1, colored by LEAD
# ggplot(df) + 
#     geom_boxplot(mapping = aes(y = YEAR2, color = LEAD))

# %%
head(df, 2)
# Out:
#   LEAD AGE SEX YEAR1 YEAR2 IQV IQP IQF
# 1 1    11  1   25    18    61  85  70
# 2 1     9  1   31    28    82  90  85

# %%
ggplot(df) + 
    geom_point(aes(YEAR2, IQF)) + 
    theme(aspect.ratio = 1)
# Out:
# plot without title

# %%
# create a regression model predicting IQF from AGE, SEX, and YEAR2
# model <- lm(formula = IQF ~ AGE + SEX + YEAR2, data = df)
model <- lm(formula = IQF ~ YEAR2, data = df)
summary(model)
# Out:
# Call:
# lm(formula = IQF ~ YEAR2, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -43.519  -7.645  -0.321   7.679  49.454
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  97.8497     4.4671  21.904   <2e-16 ***
# YEAR2        -0.2251     0.1368  -1.646    0.102
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 14.32 on 119 degrees of freedom
# Multiple R-squared:  0.02225,	Adjusted R-squared:  0.01403
# F-statistic: 2.708 on 1 and 119 DF,  p-value: 0.1025
